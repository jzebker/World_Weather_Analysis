# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a list of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
#import dependencies
from config2 import weather_api_key
import requests
from datetime import datetime
#build basic url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url).json()
city_weather["weather"][0]['description']
# Out:
# 'overcast clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i,city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 7 of Set 1 | karla
# Processing Record 8 of Set 1 | agartala
# Processing Record 9 of Set 1 | huarmey
# Processing Record 10 of Set 1 | siniscola
# Processing Record 11 of Set 1 | alappuzha
# Processing Record 12 of Set 1 | katima mulilo
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | xingcheng
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | chapais
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | olinda
# Processing Record 25 of Set 1 | ust-maya
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | ulaanbaatar
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | yanchukan
# City not found. Skipping...
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | salinopolis
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | coquimbo
# Processing Record 36 of Set 1 | juba
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | beringovskiy
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | padang
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 1 | pochutla
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | mehamn
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | seoul
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | sola
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | isangel
# Processing Record 5 of Set 2 | xinqing
# Processing Record 6 of Set 2 | muros
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | kassala
# Processing Record 9 of Set 2 | balabac
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | taltal
# Processing Record 12 of Set 2 | richards bay
# Processing Record 13 of Set 2 | nouadhibou
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | goderich
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | celendin
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | tigre
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | tautira
# Processing Record 26 of Set 2 | preston
# Processing Record 27 of Set 2 | la primavera
# Processing Record 28 of Set 2 | vao
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | kununurra
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | kaeo
# Processing Record 34 of Set 2 | camana
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 2 | athabasca
# Processing Record 37 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | dingle
# Processing Record 39 of Set 2 | belaya gora
# Processing Record 40 of Set 2 | acapulco
# Processing Record 41 of Set 2 | sangar
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | ulladulla
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | estancia
# Processing Record 47 of Set 2 | izumo
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | hualmay
# Processing Record 50 of Set 2 | muzhi
# Processing Record 1 of Set 3 | rio gallegos
# Processing Record 2 of Set 3 | mahibadhoo
# Processing Record 3 of Set 3 | yumen
# Processing Record 4 of Set 3 | norman wells
# Processing Record 5 of Set 3 | le port
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | altoona
# Processing Record 11 of Set 3 | russell
# Processing Record 12 of Set 3 | mombaca
# Processing Record 13 of Set 3 | vila velha
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | prosec
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | poum
# Processing Record 19 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 3 | mto wa mbu
# Processing Record 21 of Set 3 | estelle
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | calama
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | rheine
# Processing Record 27 of Set 3 | zhigansk
# Processing Record 28 of Set 3 | biloxi
# Processing Record 29 of Set 3 | coihaique
# Processing Record 30 of Set 3 | doha
# Processing Record 31 of Set 3 | whitehorse
# Processing Record 32 of Set 3 | lakes entrance
# Processing Record 33 of Set 3 | san cristobal
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | vila do maio
# Processing Record 36 of Set 3 | marsa matruh
# Processing Record 37 of Set 3 | canora
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | meru
# Processing Record 40 of Set 3 | nampula
# Processing Record 41 of Set 3 | taksimo
# Processing Record 42 of Set 3 | bergen
# Processing Record 43 of Set 3 | constantine
# Processing Record 44 of Set 3 | kingman
# Processing Record 45 of Set 3 | port hawkesbury
# Processing Record 46 of Set 3 | altamira
# Processing Record 47 of Set 3 | mineiros
# Processing Record 48 of Set 3 | cayenne
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | banjar
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | sibolga
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | silver city
# Processing Record 5 of Set 4 | eston
# Processing Record 6 of Set 4 | xudat
# Processing Record 7 of Set 4 | edd
# Processing Record 8 of Set 4 | shimanovsk
# Processing Record 9 of Set 4 | saint george
# Processing Record 10 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | buraydah
# Processing Record 12 of Set 4 | sakakah
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | omsukchan
# Processing Record 15 of Set 4 | cabra
# Processing Record 16 of Set 4 | kropotkin
# Processing Record 17 of Set 4 | muchkapskiy
# Processing Record 18 of Set 4 | guarapari
# Processing Record 19 of Set 4 | trinidad
# Processing Record 20 of Set 4 | truth or consequences
# Processing Record 21 of Set 4 | lorengau
# Processing Record 22 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 4 | kuah
# Processing Record 24 of Set 4 | aklavik
# Processing Record 25 of Set 4 | ewa beach
# Processing Record 26 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 4 | nikolskoye
# Processing Record 29 of Set 4 | broome
# Processing Record 30 of Set 4 | salamanca
# Processing Record 31 of Set 4 | dukat
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | nipawin
# Processing Record 34 of Set 4 | itarema
# Processing Record 35 of Set 4 | lompoc
# Processing Record 36 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 4 | carnarvon
# Processing Record 38 of Set 4 | sotouboua
# Processing Record 39 of Set 4 | pangody
# Processing Record 40 of Set 4 | sao joao do piaui
# Processing Record 41 of Set 4 | askino
# Processing Record 42 of Set 4 | salalah
# Processing Record 43 of Set 4 | dunedin
# Processing Record 44 of Set 4 | atuona
# Processing Record 45 of Set 4 | yar-sale
# Processing Record 46 of Set 4 | kodiak
# Processing Record 47 of Set 4 | myitkyina
# Processing Record 48 of Set 4 | chumikan
# Processing Record 49 of Set 4 | amga
# Processing Record 50 of Set 4 | airai
# Processing Record 1 of Set 5 | gravdal
# Processing Record 2 of Set 5 | sri aman
# Processing Record 3 of Set 5 | pilar
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | labytnangi
# Processing Record 6 of Set 5 | amapa
# Processing Record 7 of Set 5 | port keats
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | karachi
# Processing Record 10 of Set 5 | minab
# Processing Record 11 of Set 5 | saint-augustin
# Processing Record 12 of Set 5 | san policarpo
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | caravelas
# Processing Record 15 of Set 5 | khani
# Processing Record 16 of Set 5 | austin
# Processing Record 17 of Set 5 | mount gambier
# Processing Record 18 of Set 5 | tiarei
# Processing Record 19 of Set 5 | vardo
# Processing Record 20 of Set 5 | salinas
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | gillette
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | faanui
# Processing Record 25 of Set 5 | keti bandar
# Processing Record 26 of Set 5 | ziniare
# Processing Record 27 of Set 5 | tiznit
# Processing Record 28 of Set 5 | harnosand
# Processing Record 29 of Set 5 | san isidro
# Processing Record 30 of Set 5 | chokurdakh
# Processing Record 31 of Set 5 | fortuna
# Processing Record 32 of Set 5 | kibre mengist
# Processing Record 33 of Set 5 | kahului
# Processing Record 34 of Set 5 | svetlaya
# Processing Record 35 of Set 5 | puerto suarez
# Processing Record 36 of Set 5 | tamandare
# Processing Record 37 of Set 5 | wick
# Processing Record 38 of Set 5 | kiama
# Processing Record 39 of Set 5 | bethel
# Processing Record 40 of Set 5 | kautokeino
# Processing Record 41 of Set 5 | klaksvik
# Processing Record 42 of Set 5 | belyy yar
# Processing Record 43 of Set 5 | samarai
# Processing Record 44 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 45 of Set 5 | vila franca do campo
# Processing Record 46 of Set 5 | katherine
# Processing Record 47 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 5 | abu samrah
# Processing Record 49 of Set 5 | omboue
# Processing Record 50 of Set 5 | atherton
# Processing Record 1 of Set 6 | krasnyy oktyabr
# Processing Record 2 of Set 6 | oranjemund
# Processing Record 3 of Set 6 | antsohihy
# Processing Record 4 of Set 6 | perivolion
# Processing Record 5 of Set 6 | ambilobe
# Processing Record 6 of Set 6 | talnakh
# Processing Record 7 of Set 6 | monrovia
# Processing Record 8 of Set 6 | hofn
# Processing Record 9 of Set 6 | ugoofaaru
# Processing Record 10 of Set 6 | port-gentil
# Processing Record 11 of Set 6 | chuy
# Processing Record 12 of Set 6 | bilibino
# Processing Record 13 of Set 6 | zhongshu
# Processing Record 14 of Set 6 | sawtell
# Processing Record 15 of Set 6 | taikang
# Processing Record 16 of Set 6 | ayagoz
# Processing Record 17 of Set 6 | newport
# Processing Record 18 of Set 6 | kudahuvadhoo
# Processing Record 19 of Set 6 | nadym
# Processing Record 20 of Set 6 | saint-pierre
# Processing Record 21 of Set 6 | vestmannaeyjar
# Processing Record 22 of Set 6 | tateyama
# Processing Record 23 of Set 6 | sao filipe
# Processing Record 24 of Set 6 | bud
# Processing Record 25 of Set 6 | alexandria
# Processing Record 26 of Set 6 | mar del plata
# Processing Record 27 of Set 6 | ferrol
# Processing Record 28 of Set 6 | tripoli
# Processing Record 29 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 6 | japura
# Processing Record 31 of Set 6 | boffa
# Processing Record 32 of Set 6 | shihezi
# Processing Record 33 of Set 6 | mbamba
# Processing Record 34 of Set 6 | duz
# City not found. Skipping...
# Processing Record 35 of Set 6 | chagoda
# Processing Record 36 of Set 6 | mnisek pod brdy
# Processing Record 37 of Set 6 | masallatah
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | stratford-upon-avon
# Processing Record 40 of Set 6 | vermilion
# Processing Record 41 of Set 6 | pucara
# Processing Record 42 of Set 6 | alice springs
# Processing Record 43 of Set 6 | jasper
# Processing Record 44 of Set 6 | kaihua
# Processing Record 45 of Set 6 | uyskoye
# Processing Record 46 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 6 | guerrero negro
# Processing Record 48 of Set 6 | mopipi
# Processing Record 49 of Set 6 | roura
# Processing Record 50 of Set 6 | anamur
# Processing Record 1 of Set 7 | cerro punta
# Processing Record 2 of Set 7 | ostrovnoy
# Processing Record 3 of Set 7 | kampong thum
# Processing Record 4 of Set 7 | robat karim
# Processing Record 5 of Set 7 | faya
# Processing Record 6 of Set 7 | karratha
# Processing Record 7 of Set 7 | mopti
# Processing Record 8 of Set 7 | usinsk
# Processing Record 9 of Set 7 | smithers
# Processing Record 10 of Set 7 | tilichiki
# Processing Record 11 of Set 7 | labuhan
# Processing Record 12 of Set 7 | san patricio
# Processing Record 13 of Set 7 | araripina
# Processing Record 14 of Set 7 | maceio
# Processing Record 15 of Set 7 | pokrovsk
# Processing Record 16 of Set 7 | binzhou
# Processing Record 17 of Set 7 | pitimbu
# Processing Record 18 of Set 7 | komsomolskiy
# Processing Record 19 of Set 7 | raga
# Processing Record 20 of Set 7 | vylkove
# Processing Record 21 of Set 7 | troitsko-pechorsk
# Processing Record 22 of Set 7 | enshi
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | auki
# Processing Record 25 of Set 7 | chipata
# Processing Record 26 of Set 7 | avera
# Processing Record 27 of Set 7 | lagunas
# Processing Record 28 of Set 7 | pevek
# Processing Record 29 of Set 7 | inirida
# Processing Record 30 of Set 7 | tuatapere
# Processing Record 31 of Set 7 | veraval
# Processing Record 32 of Set 7 | touros
# Processing Record 33 of Set 7 | iqaluit
# Processing Record 34 of Set 7 | lasa
# Processing Record 35 of Set 7 | west bay
# Processing Record 36 of Set 7 | fare
# Processing Record 37 of Set 7 | staritsa
# Processing Record 38 of Set 7 | wylie
# Processing Record 39 of Set 7 | qasigiannguit
# Processing Record 40 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 7 | magistralnyy
# Processing Record 42 of Set 7 | dordrecht
# Processing Record 43 of Set 7 | burnie
# Processing Record 44 of Set 7 | okha
# Processing Record 45 of Set 7 | abeche
# Processing Record 46 of Set 7 | ilulissat
# Processing Record 47 of Set 7 | puerto baquerizo moreno
# Processing Record 48 of Set 7 | khandyga
# Processing Record 49 of Set 7 | posadas
# Processing Record 50 of Set 7 | jieshi
# Processing Record 1 of Set 8 | bereda
# Processing Record 2 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 8 | eyl
# Processing Record 4 of Set 8 | jakar
# Processing Record 5 of Set 8 | yongan
# Processing Record 6 of Set 8 | lucapa
# Processing Record 7 of Set 8 | matagami
# Processing Record 8 of Set 8 | berlevag
# Processing Record 9 of Set 8 | tezu
# Processing Record 10 of Set 8 | grindavik
# Processing Record 11 of Set 8 | ferme-neuve
# Processing Record 12 of Set 8 | esperance
# Processing Record 13 of Set 8 | kurchum
# Processing Record 14 of Set 8 | abha
# Processing Record 15 of Set 8 | sistranda
# Processing Record 16 of Set 8 | lubao
# Processing Record 17 of Set 8 | charters towers
# Processing Record 18 of Set 8 | shellbrook
# Processing Record 19 of Set 8 | presidente medici
# Processing Record 20 of Set 8 | bardiyah
# Processing Record 21 of Set 8 | meulaboh
# Processing Record 22 of Set 8 | mnogovershinnyy
# Processing Record 23 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 8 | kamsack
# Processing Record 25 of Set 8 | show low
# Processing Record 26 of Set 8 | los llanos de aridane
# Processing Record 27 of Set 8 | mulchen
# Processing Record 28 of Set 8 | bakal
# Processing Record 29 of Set 8 | san carlos de bariloche
# Processing Record 30 of Set 8 | hovd
# Processing Record 31 of Set 8 | balikpapan
# Processing Record 32 of Set 8 | linares
# Processing Record 33 of Set 8 | manfredonia
# Processing Record 34 of Set 8 | aquiraz
# Processing Record 35 of Set 8 | tsiroanomandidy
# Processing Record 36 of Set 8 | high level
# Processing Record 37 of Set 8 | adrar
# Processing Record 38 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 8 | vanimo
# Processing Record 40 of Set 8 | emmen
# Processing Record 41 of Set 8 | nishihara
# Processing Record 42 of Set 8 | jinchang
# Processing Record 43 of Set 8 | zhuanghe
# Processing Record 44 of Set 8 | asau
# Processing Record 45 of Set 8 | lixourion
# Processing Record 46 of Set 8 | holme
# Processing Record 47 of Set 8 | hobyo
# Processing Record 48 of Set 8 | berdigestyakh
# Processing Record 49 of Set 8 | cockburn town
# Processing Record 50 of Set 8 | riyadh
# Processing Record 1 of Set 9 | port hedland
# Processing Record 2 of Set 9 | plonsk
# Processing Record 3 of Set 9 | beloha
# Processing Record 4 of Set 9 | nyurba
# Processing Record 5 of Set 9 | san luis
# Processing Record 6 of Set 9 | anadyr
# Processing Record 7 of Set 9 | agadir
# Processing Record 8 of Set 9 | lagoa
# Processing Record 9 of Set 9 | adre
# Processing Record 10 of Set 9 | ilo
# Processing Record 11 of Set 9 | kihei
# Processing Record 12 of Set 9 | sitka
# Processing Record 13 of Set 9 | dipkarpaz
# City not found. Skipping...
# Processing Record 14 of Set 9 | lincoln
# Processing Record 15 of Set 9 | fukue
# Processing Record 16 of Set 9 | katsuura
# Processing Record 17 of Set 9 | namanga
# Processing Record 18 of Set 9 | banes
# Processing Record 19 of Set 9 | ust-ilimsk
# Processing Record 20 of Set 9 | pangnirtung
# Processing Record 21 of Set 9 | honningsvag
# Processing Record 22 of Set 9 | ivanivka
# Processing Record 23 of Set 9 | mangochi
# Processing Record 24 of Set 9 | dwarka
# Processing Record 25 of Set 9 | polazna
# Processing Record 26 of Set 9 | hede
# Processing Record 27 of Set 9 | umm lajj
# Processing Record 28 of Set 9 | kloulklubed
# Processing Record 29 of Set 9 | ibirama
# Processing Record 30 of Set 9 | sapele
# Processing Record 31 of Set 9 | port lincoln
# Processing Record 32 of Set 9 | chama
# Processing Record 33 of Set 9 | viedma
# Processing Record 34 of Set 9 | ust-nera
# Processing Record 35 of Set 9 | valparaiso
# Processing Record 36 of Set 9 | karaton
# Processing Record 37 of Set 9 | henties bay
# Processing Record 38 of Set 9 | suntar
# Processing Record 39 of Set 9 | pontal do parana
# Processing Record 40 of Set 9 | sipovo
# Processing Record 41 of Set 9 | chimore
# Processing Record 42 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 9 | asnaes
# Processing Record 44 of Set 9 | ipixuna
# Processing Record 45 of Set 9 | toro
# Processing Record 46 of Set 9 | ati
# Processing Record 47 of Set 9 | videira
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | rorvik
# Processing Record 50 of Set 9 | santo domingo
# Processing Record 1 of Set 10 | nara
# Processing Record 2 of Set 10 | san francisco
# Processing Record 3 of Set 10 | bathsheba
# Processing Record 4 of Set 10 | totness
# Processing Record 5 of Set 10 | sabha
# Processing Record 6 of Set 10 | tigil
# Processing Record 7 of Set 10 | prince rupert
# Processing Record 8 of Set 10 | garden city
# Processing Record 9 of Set 10 | floriano
# Processing Record 10 of Set 10 | hudson bay
# Processing Record 11 of Set 10 | limbang
# Processing Record 12 of Set 10 | grand gaube
# Processing Record 13 of Set 10 | pisco
# Processing Record 14 of Set 10 | yaroslavskiy
# Processing Record 15 of Set 10 | irbit
# Processing Record 16 of Set 10 | kailua
# Processing Record 17 of Set 10 | oktyabrskiy
# Processing Record 18 of Set 10 | ornskoldsvik
# Processing Record 19 of Set 10 | lata
# Processing Record 20 of Set 10 | provideniya
# Processing Record 21 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 22 of Set 10 | castlecomer
# Processing Record 23 of Set 10 | severo-yeniseyskiy
# Processing Record 24 of Set 10 | isabela
# Processing Record 25 of Set 10 | sainte-rose
# Processing Record 26 of Set 10 | emerald
# Processing Record 27 of Set 10 | gympie
# Processing Record 28 of Set 10 | emba
# Processing Record 29 of Set 10 | nantucket
# Processing Record 30 of Set 10 | victor harbor
# Processing Record 31 of Set 10 | kysyl-syr
# Processing Record 32 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 10 | paita
# Processing Record 34 of Set 10 | qadirpur ran
# Processing Record 35 of Set 10 | tornio
# Processing Record 36 of Set 10 | altay
# Processing Record 37 of Set 10 | alta floresta
# Processing Record 38 of Set 10 | gazojak
# Processing Record 39 of Set 10 | yaan
# Processing Record 40 of Set 10 | yulara
# Processing Record 41 of Set 10 | taoudenni
# Processing Record 42 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 10 | shenjiamen
# Processing Record 44 of Set 10 | jacareacanga
# Processing Record 45 of Set 10 | mountain home
# Processing Record 46 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 10 | comodoro rivadavia
# Processing Record 48 of Set 10 | auray
# Processing Record 49 of Set 10 | bhatkal
# Processing Record 50 of Set 10 | kilifi
# Processing Record 1 of Set 11 | portland
# Processing Record 2 of Set 11 | xining
# Processing Record 3 of Set 11 | turukhansk
# Processing Record 4 of Set 11 | kavieng
# Processing Record 5 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 11 | laguna
# Processing Record 7 of Set 11 | agirish
# Processing Record 8 of Set 11 | babanka
# Processing Record 9 of Set 11 | okhotsk
# Processing Record 10 of Set 11 | marsh harbour
# Processing Record 11 of Set 11 | coruripe
# Processing Record 12 of Set 11 | waipawa
# Processing Record 13 of Set 11 | tomatlan
# Processing Record 14 of Set 11 | haines junction
# Processing Record 15 of Set 11 | maumere
# Processing Record 16 of Set 11 | piacabucu
# Processing Record 17 of Set 11 | kilindoni
# Processing Record 18 of Set 11 | lazaro cardenas
# Processing Record 19 of Set 11 | fort walton beach
# Processing Record 20 of Set 11 | sisophon
# Processing Record 21 of Set 11 | hoquiam
# Processing Record 22 of Set 11 | nanortalik
# Processing Record 23 of Set 11 | naberera
# Processing Record 24 of Set 11 | ko samui
# Processing Record 25 of Set 11 | hamilton
# Processing Record 26 of Set 11 | keratea
# Processing Record 27 of Set 11 | miraflores
# Processing Record 28 of Set 11 | bolobo
# Processing Record 29 of Set 11 | saint pete beach
# Processing Record 30 of Set 11 | heinola
# Processing Record 31 of Set 11 | smoky lake
# Processing Record 32 of Set 11 | galle
# Processing Record 33 of Set 11 | jizan
# Processing Record 34 of Set 11 | srednekolymsk
# Processing Record 35 of Set 11 | milton
# Processing Record 36 of Set 11 | wuwei
# Processing Record 37 of Set 11 | port macquarie
# Processing Record 38 of Set 11 | oranjestad
# Processing Record 39 of Set 11 | quarai
# Processing Record 40 of Set 11 | buchanan
# Processing Record 41 of Set 11 | harper
# Processing Record 42 of Set 11 | buenaventura
# Processing Record 43 of Set 11 | dumai
# Processing Record 44 of Set 11 | halifax
# Processing Record 45 of Set 11 | tipuani
# Processing Record 46 of Set 11 | roald
# Processing Record 47 of Set 11 | talaya
# Processing Record 48 of Set 11 | sao gabriel da cachoeira
# Processing Record 49 of Set 11 | huanren
# Processing Record 50 of Set 11 | pedernales
# Processing Record 1 of Set 12 | abnub
# Processing Record 2 of Set 12 | evensk
# Processing Record 3 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 12 | havoysund
# Processing Record 5 of Set 12 | nehe
# Processing Record 6 of Set 12 | lar
# Processing Record 7 of Set 12 | buala
# Processing Record 8 of Set 12 | sinnamary
# Processing Record 9 of Set 12 | bantacan
# Processing Record 10 of Set 12 | canon city
# Processing Record 11 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 12 of Set 12 | port-cartier
# Processing Record 13 of Set 12 | paamiut
# Processing Record 14 of Set 12 | peniche
# Processing Record 15 of Set 12 | dauphin
# Processing Record 16 of Set 12 | mala
# Processing Record 17 of Set 12 | myaundzha
# Processing Record 18 of Set 12 | ahipara
# Processing Record 19 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 12 | khasan
# Processing Record 21 of Set 12 | opuwo
# Processing Record 22 of Set 12 | inuvik
# Processing Record 23 of Set 12 | dali
# Processing Record 24 of Set 12 | przhevalskoye
# Processing Record 25 of Set 12 | dicabisagan
# Processing Record 26 of Set 12 | wanaka
# Processing Record 27 of Set 12 | strelka
# Processing Record 28 of Set 12 | kieta
# Processing Record 29 of Set 12 | santo antonio do sudoeste
# Processing Record 30 of Set 12 | fort nelson
# Processing Record 31 of Set 12 | mazatan
# Processing Record 32 of Set 12 | general pico
# Processing Record 33 of Set 12 | igarka
# Processing Record 34 of Set 12 | pizarro
# Processing Record 35 of Set 12 | san rafael
# Processing Record 36 of Set 12 | la ronge
# Processing Record 37 of Set 12 | los banos
# Processing Record 38 of Set 12 | cururupu
# Processing Record 39 of Set 12 | sungaipenuh
# Processing Record 40 of Set 12 | mizdah
# Processing Record 41 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 42 of Set 12 | kerrobert
# Processing Record 43 of Set 12 | narsaq
# Processing Record 44 of Set 12 | lyubar
# Processing Record 45 of Set 12 | kirakira
# Processing Record 46 of Set 12 | williamsburg
# Processing Record 47 of Set 12 | tarifa
# Processing Record 48 of Set 12 | pasighat
# Processing Record 49 of Set 12 | yerbogachen
# Processing Record 50 of Set 12 | tombouctou
# Processing Record 1 of Set 13 | megion
# Processing Record 2 of Set 13 | tura
# Processing Record 3 of Set 13 | baturaja
# Processing Record 4 of Set 13 | santa maria
# Processing Record 5 of Set 13 | ilheus
# Processing Record 6 of Set 13 | de pere
# Processing Record 7 of Set 13 | makakilo city
# Processing Record 8 of Set 13 | karasjok
# Processing Record 9 of Set 13 | sao felix do xingu
# Processing Record 10 of Set 13 | kyra
# Processing Record 11 of Set 13 | saint anthony
# Processing Record 12 of Set 13 | ekangala
# Processing Record 13 of Set 13 | misratah
# Processing Record 14 of Set 13 | zhuozhou
# City not found. Skipping...
# Processing Record 15 of Set 13 | nyirbogdany
# Processing Record 16 of Set 13 | noumea
# Processing Record 17 of Set 13 | lufilufi
# Processing Record 18 of Set 13 | cap malheureux
# Processing Record 19 of Set 13 | talcahuano
# Processing Record 20 of Set 13 | college
# Processing Record 21 of Set 13 | shingu
# Processing Record 22 of Set 13 | marawi
# Processing Record 23 of Set 13 | helong
# Processing Record 24 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 13 | geraldton
# Processing Record 26 of Set 13 | christchurch
# Processing Record 27 of Set 13 | yarmouth
# Processing Record 28 of Set 13 | cuiluan
# Processing Record 29 of Set 13 | nyrob
# Processing Record 30 of Set 13 | barstow
# Processing Record 31 of Set 13 | bandarbeyla
# Processing Record 32 of Set 13 | koumac
# Processing Record 33 of Set 13 | sur
# Processing Record 34 of Set 13 | namibe
# Processing Record 35 of Set 13 | barra dos coqueiros
# Processing Record 36 of Set 13 | koungheul
# Processing Record 37 of Set 13 | oistins
# Processing Record 38 of Set 13 | port augusta
# Processing Record 39 of Set 13 | port blair
# Processing Record 40 of Set 13 | carndonagh
# Processing Record 41 of Set 13 | gurupa
# Processing Record 42 of Set 13 | bondo
# Processing Record 43 of Set 13 | brae
# Processing Record 44 of Set 13 | deputatskiy
# Processing Record 45 of Set 13 | santa maria ixhuatan
# Processing Record 46 of Set 13 | uruzgan
# Processing Record 47 of Set 13 | biltine
# Processing Record 48 of Set 13 | humberto de campos
# Processing Record 49 of Set 13 | narodychi
# Processing Record 50 of Set 13 | fairbanks
# Processing Record 1 of Set 14 | abalak
# Processing Record 2 of Set 14 | severnoye
# Processing Record 3 of Set 14 | najran
# Processing Record 4 of Set 14 | ballina
# Processing Record 5 of Set 14 | paragominas
# Processing Record 6 of Set 14 | prieska
# Processing Record 7 of Set 14 | vanderhoof
# Processing Record 8 of Set 14 | osakarovka
# Processing Record 9 of Set 14 | pemangkat
# Processing Record 10 of Set 14 | dunhua
# Processing Record 11 of Set 14 | ambanja
# Processing Record 12 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 13 of Set 14 | nargana
# Processing Record 14 of Set 14 | el seibo
# Processing Record 15 of Set 14 | alfonsine
# Processing Record 16 of Set 14 | egvekinot
# Processing Record 17 of Set 14 | manzanillo
# Processing Record 18 of Set 14 | salta
# Processing Record 19 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 14 | sfantu gheorghe
# Processing Record 21 of Set 14 | el dovio
# Processing Record 22 of Set 14 | sao jose da coroa grande
# Processing Record 23 of Set 14 | naro
# Processing Record 24 of Set 14 | afsin
# Processing Record 25 of Set 14 | lago da pedra
# Processing Record 26 of Set 14 | san quintin
# Processing Record 27 of Set 14 | palmer
# Processing Record 28 of Set 14 | tessalit
# Processing Record 29 of Set 14 | qena
# Processing Record 30 of Set 14 | shelburne
# Processing Record 31 of Set 14 | morales
# Processing Record 32 of Set 14 | toledo
# Processing Record 33 of Set 14 | bandundu
# Processing Record 34 of Set 14 | lavrentiya
# Processing Record 35 of Set 14 | candolim
# Processing Record 36 of Set 14 | san juan
# Processing Record 37 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 14 | vangaindrano
# Processing Record 39 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 40 of Set 14 | nouakchott
# Processing Record 41 of Set 14 | mount pleasant
# Processing Record 42 of Set 14 | beyneu
# Processing Record 43 of Set 14 | asfi
# Processing Record 44 of Set 14 | biella
# Processing Record 45 of Set 14 | careiro da varzea
# Processing Record 46 of Set 14 | severo-kurilsk
# Processing Record 47 of Set 14 | ahuimanu
# Processing Record 48 of Set 14 | karabuk
# Processing Record 49 of Set 14 | tucuman
# Processing Record 50 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 15 | lebanon
# Processing Record 3 of Set 15 | police
# Processing Record 4 of Set 15 | north bend
# Processing Record 5 of Set 15 | teguise
# Processing Record 6 of Set 15 | twante
# Processing Record 7 of Set 15 | zhangye
# Processing Record 8 of Set 15 | akdagmadeni
# Processing Record 9 of Set 15 | xuddur
# Processing Record 10 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 11 of Set 15 | point pleasant
# Processing Record 12 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 15 | manosque
# Processing Record 14 of Set 15 | los zacatones
# Processing Record 15 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 15 | verkhoyansk
# Processing Record 17 of Set 15 | harindanga
# Processing Record 18 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 19 of Set 15 | lancaster
# Processing Record 20 of Set 15 | khandbari
# Processing Record 21 of Set 15 | sefton
# Processing Record 22 of Set 15 | chabahar
# Processing Record 23 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 24 of Set 15 | kolimvari
# City not found. Skipping...
# Processing Record 25 of Set 15 | kuytun
# Processing Record 26 of Set 15 | elliot
# Processing Record 27 of Set 15 | nova russas
# Processing Record 28 of Set 15 | kaberamaido
# Processing Record 29 of Set 15 | kalemie
# Processing Record 30 of Set 15 | saint simons
# Processing Record 31 of Set 15 | energetik
# Processing Record 32 of Set 15 | dhidhdhoo
# Processing Record 33 of Set 15 | otradnoye
# Processing Record 34 of Set 15 | raubling
# Processing Record 35 of Set 15 | orocue
# Processing Record 36 of Set 15 | bonthe
# Processing Record 37 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 15 | kamaishi
# Processing Record 39 of Set 15 | maniitsoq
# Processing Record 40 of Set 15 | bosaso
# Processing Record 41 of Set 15 | chenghai
# Processing Record 42 of Set 15 | hastings
# Processing Record 43 of Set 15 | bartica
# Processing Record 44 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 15 | vila
# Processing Record 46 of Set 15 | axim
# Processing Record 47 of Set 15 | boguchany
# Processing Record 48 of Set 15 | aybak
# City not found. Skipping...
# Processing Record 49 of Set 15 | korla
# Processing Record 50 of Set 15 | zhezkazgan
# Processing Record 1 of Set 16 | gabu
# Processing Record 2 of Set 16 | payson
# Processing Record 3 of Set 16 | te anau
# Processing Record 4 of Set 16 | manokwari
# Processing Record 5 of Set 16 | fasa
# Processing Record 6 of Set 16 | sapouy
# Processing Record 7 of Set 16 | latisana
# Processing Record 8 of Set 16 | kavaratti
# Processing Record 9 of Set 16 | fuling
# Processing Record 10 of Set 16 | alamosa
# Processing Record 11 of Set 16 | bogorodskoye
# Processing Record 12 of Set 16 | sarakhs
# Processing Record 13 of Set 16 | wajir
# Processing Record 14 of Set 16 | itoman
# Processing Record 15 of Set 16 | matara
# Processing Record 16 of Set 16 | the valley
# Processing Record 17 of Set 16 | kuala terengganu
# Processing Record 18 of Set 16 | hirara
# Processing Record 19 of Set 16 | pau
# Processing Record 20 of Set 16 | sorrento
# Processing Record 21 of Set 16 | polovinnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_columns = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_columns]
# Format latitude and longitude to 2 decimal places
city_data_df['Lat'] = city_data_df['Lat'].map("{:,.2f}".format)
city_data_df['Lng'] = city_data_df['Lng'].map("{:,.2f}".format)
city_data_df.head(15)
# Out:
#              City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Tuktoyaktuk      CA   69.45  -133.04     68.00        64          75
# 1         Ushuaia      AR  -54.80   -68.30     40.66        70          20
# 2        Saldanha      ZA  -33.01    17.94     53.65        70         100
# 3          Castro      BR  -24.79   -50.01     41.32        68           8
# 4    Kruisfontein      ZA  -34.00    24.73     51.89        90         100
# 5           Karla      EE   59.37    24.93     64.36        60          75
# 6        Agartala      IN   23.84    91.28     76.95        96         100
# 7         Huarmey      PE  -10.07   -78.15     67.23        74          13
# 8       Siniscola      IT   40.57     9.69     72.95        59           0
# 9       Alappuzha      IN    9.49    76.33     78.24        86          90
# 10  Katima Mulilo      NA  -17.50    24.27     52.11        44           0
# 11           Hilo      US   19.73  -155.09     80.80        86          90
# 12      Xingcheng      CN   40.62   120.72     74.12        90          75
# 13       Hermanus      ZA  -34.42    19.23     50.90        80         100
# 14        Rikitea      PF  -23.12  -134.97     71.06        66         100
#
#     Wind Speed Current Description
# 0         9.22       broken clouds
# 1         9.22          few clouds
# 2        16.55     overcast clouds
# 3         1.21           clear sky
# 4         6.64     overcast clouds
# 5        10.36       broken clouds
# 6         5.99       moderate rain
# 7         8.93          few clouds
# 8         4.79           clear sky
# 9        10.22     overcast clouds
# 10        4.61           clear sky
# 11        8.05          light rain
# 12        0.78       broken clouds
# 13        1.90          light rain
# 14       24.85          light rain

# %%
# Export DataFrame to CSV
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="Index")
